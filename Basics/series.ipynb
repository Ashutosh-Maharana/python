# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
obj = Series([3,6,9,12])
#series object = indexed

# %%
obj
# Out:
# 0     3
# 1     6
# 2     9
# 3    12
# dtype: int64

# %%
obj.values
# Out:
# array([ 3,  6,  9, 12], dtype=int64)

# %%
obj.index.values
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
ww2_cas = Series([8.7, 4.3, 3, 2.1,0.4],index=['USSR','Germany','China','Japan','USA'])

# %%
ww2_cas
# Out:
# USSR       8.7
# Germany    4.3
# China      3.0
# Japan      2.1
# USA        0.4
# dtype: float64

# %%
ww2_cas['China']
# Out:
# 3.0

# %%
#high casualty

# %%
ww2_cas[ ww2_cas > 4]
# Out:
# USSR       8.7
# Germany    4.3
# dtype: float64

# %%
a = ww2_cas[ ww2_cas > 4]

# %%
a
# Out:
# USSR       8.7
# Germany    4.3
# dtype: float64

# %%
a.dtype
# Out:
# dtype('float64')

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
'USA' in ww2_cas
#series behaves like a dictionary
# Out:
# True

# %%
ww2_dict = ww2_cas.to_dict()

# %%
ww2_dict
# Out:
# {'USSR': 8.7, 'Germany': 4.3, 'China': 3.0, 'Japan': 2.1, 'USA': 0.4}

# %%
'ussr' in ww2_dict
# Out:
# False

# %%
'USSR' in ww2_dict
# Out:
# True

# %%
ww2_series = Series(ww2_dict)
ww2_series
# Out:
# USSR       8.7
# Germany    4.3
# China      3.0
# Japan      2.1
# USA        0.4
# dtype: float64

# %%
num = [1,2,3,4,5,6]

# %%
obj = Series(ww2_dict, index = num)

# %%
obj
# Out:
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# dtype: float64

# %%
c = ['China','USSR','Russia','USA','Germany','f']

# %%
obj = Series(ww2_dict,index = c)

# %%
obj
# Out:
# China      3.0
# USSR       8.7
# Russia     NaN
# USA        0.4
# Germany    4.3
# f          NaN
# dtype: float64

# %%
obj = Series(ww2_series,index = c)

# %%
obj
# Out:
# China      3.0
# USSR       8.7
# Russia     NaN
# USA        0.4
# Germany    4.3
# f          NaN
# dtype: float64

# %%
#takes the index values from index, matches the index-value from original dict/series or uses null for non-matching index

# %%
pd.isnull(obj)
# Out:
# China      False
# USSR       False
# Russia      True
# USA        False
# Germany    False
# f           True
# dtype: bool

# %%
pd.notnull(obj)
# Out:
# China       True
# USSR        True
# Russia     False
# USA         True
# Germany     True
# f          False
# dtype: bool

# %%
ww2_series
# Out:
# USSR       8.7
# Germany    4.3
# China      3.0
# Japan      2.1
# USA        0.4
# dtype: float64

# %%
obj
# Out:
# China      3.0
# USSR       8.7
# Russia     NaN
# USA        0.4
# Germany    4.3
# f          NaN
# dtype: float64

# %%
ww2_series + obj
# Out:
# China       6.0
# Germany     8.6
# Japan       NaN
# Russia      NaN
# USA         0.8
# USSR       17.4
# f           NaN
# dtype: float64

# %%
obj.name = "ww2 casualties"

# %%
obj
# Out:
# China      3.0
# USSR       8.7
# Russia     NaN
# USA        0.4
# Germany    4.3
# f          NaN
# Name: ww2 casualties, dtype: float64

# %%
obj.index.name = "Countries"

# %%
obj
# Out:
# Countries
# China      3.0
# USSR       8.7
# Russia     NaN
# USA        0.4
# Germany    4.3
# f          NaN
# Name: ww2 casualties, dtype: float64

# %%
obj.values.name = 'causalties'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32988\3614470369.py in <module>
# ----> 1 obj.values.name = 'causalties'
#
# AttributeError: 'numpy.ndarray' object has no attribute 'name'

# %%
import pandas as pd

# Create a Series
obj = pd.Series([3.0, 8.7, None, 0.4, 4.3, None], index=["China", "USSR", "Russia", "USA", "Germany", "France"])

# Name the Series
obj.name = 'WW2 Casualties'

# Name the index (countries)
obj.index.name = 'Countries'

# Display the Series
print(obj)
# Out:
# Countries
# China      3.0
# USSR       8.7
# Russia     NaN
# USA        0.4
# Germany    4.3
# France     NaN
# Name: WW2 Casualties, dtype: float64

# %% [markdown]
# ![image.png](attachment:image.png)
